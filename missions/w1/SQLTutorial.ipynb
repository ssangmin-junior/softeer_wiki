# %%
import sqlite3  # sqlite3 모듈 임포트
import pandas as pd  # pandas 모듈 임포트

# 엑셀 파일 경로
excel_file = '/Users/admin/Documents/GitHub/softeer_wiki/missions/w1/sqltut.xlsx'

# 데이터베이스 파일 경로
database_file = 'df3.db'

# 엑셀 파일을 판다스 데이터프레임으로 읽기 (모든 시트)
xls = pd.ExcelFile(excel_file)

# SQLite 데이터베이스 연결 생성
conn = sqlite3.connect(database_file)

# 각 시트를 반복하면서 데이터베이스에 테이블로 저장
for sheet_name in xls.sheet_names:
    # 각 시트를 데이터프레임으로 변환
    df = pd.read_excel(xls, sheet_name=sheet_name)
    df.set_index(df.columns[0],inplace=True)
    df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
    
    # 데이터프레임을 SQLite 데이터베이스 테이블로 저장
    df.to_sql(sheet_name, conn, if_exists='replace', index=False)
# Out:
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)
# /var/folders/gv/h6tkbjcs4j325ypvzj8m08qc0000gn/T/ipykernel_4310/3469558131.py:21: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace('\xa0','').replace('\xa9','') if isinstance(x, str) else x)

# %%
df
# Out:
#                                       SupplierName  \
# SupplierID
# 1                                    Exotic Liquid
# 2                       New Orleans Cajun Delights
# 3                        Grandma Kelly's Homestead
# 4                                    Tokyo Traders
# 5               Cooperativa de Quesos 'Las Cabras'
# 6                                         Mayumi's
# 7                                    Pavlova, Ltd.
# 8                         Specialty Biscuits, Ltd.
# 9                                 PB Knäckebröd AB
# 10                       Refrescos Americanas LTDA
# 11                     Heli Süßwaren GmbH & Co. KG
# 12               Plutzer Lebensmittelgroßmärkte AG
# 13          Nord-Ost-Fisch Handelsgesellschaft mbH
# 14                         Formaggi Fortini s.r.l.
# 15                                 Norske Meierier
# 16                               Bigfoot Breweries
# 17                               Svensk Sjöföda AB
# 18                      Aux joyeux ecclésiastiques
# 19                     New England Seafood Cannery
# 20                                    Leka Trading
# 21                                      Lyngbysild
# 22                             Zaanse Snoepfabriek
# 23                                       Karkki Oy
# 24                                     G'day, Mate
# 25                                       Ma Maison
# 26                            Pasta Buttini s.r.l.
# 27                              Escargots Nouveaux
# 28                                    Gai pâturage
# 29                                Forêts d'érables
#
#                             ContactName  \
# SupplierID
# 1                      Charlotte Cooper
# 2                         Shelley Burke
# 3                         Regina Murphy
# 4                          Yoshi Nagase
# 5           Antonio del Valle Saavedra
# 6                           Mayumi Ohno
# 7                           Ian Devling
# 8                          Peter Wilson
# 9                         Lars Peterson
# 10                          Carlos Diaz
# 11                        Petra Winkler
# 12                          Martin Bein
# 13                        Sven Petersen
# 14                           Elio Rossi
# 15                         Beate Vileid
# 16                        Cheryl Saylor
# 17                        Michael Björn
# 18                       Guylène Nodier
# 19                        Robb Merchant
# 20                         Chandra Leka
# 21                       Niels Petersen
# 22                          Dirk Luchte
# 23                       Anne Heikkonen
# 24                      Wendy Mackenzie
# 25                      Jean-Guy Lauzon
# 26                     Giovanni Giudici
# 27                       Marie Delamare
# 28                           Eliane Noz
# 29                       Chantal Goulet
#
#                                                   Address           City  \
# SupplierID
# 1                                          49 Gilbert St.        Londona
# 2                                          P.O. Box 78934    New Orleans
# 3                                          707 Oxford Rd.      Ann Arbor
# 4                               9-8 Sekimai Musashino-shi          Tokyo
# 5                                       Calle del Rosal 4         Oviedo
# 6                                      92 Setsuko Chuo-ku          Osaka
# 7                                74 Rose St. Moonie Ponds      Melbourne
# 8                                           29 King's Way     Manchester
# 9                                         Kaloadagatan 13       Göteborg
# 10                              Av. das Americanas 12.890      São Paulo
# 11                                     Tiergartenstraße 5         Berlin
# 12                                          Bogenallee 51      Frankfurt
# 13                                       Frahmredder 112a       Cuxhaven
# 14                                        Viale Dante, 75        Ravenna
# 15                                           Hatlevegen 5       Sandvika
# 16                            3400 - 8th Avenue Suite 210           Bend
# 17                                      Brovallavägen 231      Stockholm
# 18                          203, Rue des Francs-Bourgeois          Paris
# 19          Order Processing Dept. 2100 Paul Revere Blvd.         Boston
# 20                         471 Serangoon Loop, Suite #402      Singapore
# 21                              Lyngbysild Fiskebakken 10         Lyngby
# 22                                     Verkoop Rijnweg 22        Zaandam
# 23                                           Valtakatu 12   Lappeenranta
# 24                 170 Prince Edward Parade Hunter's Hill         Sydney
# 25                                   2960 Rue St. Laurent       Montréal
# 26                                 Via dei Gelsomini, 153        Salerno
# 27                                      22, rue H. Voiron       Montceau
# 28                                Bat. B 3, rue des Alpes         Annecy
# 29                                       148 rue Chasseur  Ste-Hyacinthe
#
#            PostalCode      Country            Phone
# SupplierID
# 1             EC1 4SD           UK   (171) 555-2222
# 2               70117          USA   (100) 555-4822
# 3               48104          USA   (313) 555-5735
# 4                 100        Japan   (03) 3555-5011
# 5               33007        Spain   (98) 598 76 54
# 6                 545        Japan    (06) 431-7877
# 7                3058    Australia    (03) 444-2343
# 8             M14 GSD           UK   (161) 555-4448
# 9            S-345 67      Sweden     031-987 65 43
# 10               5442       Brazil    (11) 555 4640
# 11              10785      Germany    (010) 9984510
# 12              60439      Germany     (069) 992755
# 13              27478      Germany     (04721) 8713
# 14              48100        Italy     (0544) 60323
# 15               1320       Norway      (0)2-953010
# 16              97101          USA   (503) 555-9931
# 17           S-123 45       Sweden     08-123 45 67
# 18              75004       France  (1) 03.83.00.68
# 19              02134          USA   (617) 555-3267
# 20               0512    Singapore         555-8787
# 21               2800      Denmark         43844108
# 22            9999 ZZ  Netherlands     (12345) 1212
# 23              53120      Finland      (953) 10956
# 24               2042    Australia    (02) 555-5914
# 25            H1J 1C3       Canada   (514) 555-9022
# 26              84100        Italy    (089) 6547665
# 27              71300       France      85.57.00.07
# 28              74000       France      38.76.98.06
# 29            J2S 7S8       Canada   (514) 555-2955

# %%
cursor = conn.cursor()
query='SELECT * FROM Customers;'
cursor.execute(query)
result= cursor.fetchone()

for row in cursor:
    print(row)
# Out:
# ('Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# ('Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# ('Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# ('Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# ('Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# ('Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')
# ('Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain')
# ("Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France')
# ('Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada')
# ("B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# ('Cactus Comidas para llevar', 'Patricio Simpson', 'Cerrito 333', 'Buenos Aires', '1010', 'Argentina')
# ('Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '05022', 'Mexico')
# ('Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland')
# ('Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil')
# ('Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery ', 'London', 'WX1 6LT', 'UK')
# ('Drachenblut Delikatessend', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany')
# ('Du monde entier', 'Janine Labrune', '67, rue des Cinquante Otages', 'Nantes', '44000', 'France')
# ('Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# ('Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria')
# ('Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil')
# ('FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal, 86', 'Madrid', '28034', 'Spain')
# ('Folies gourmandes', 'Martine Rancé', '184, chaussée de Tournai', 'Lille', '59000', 'France')
# ('Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden')
# ('Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany')
# ('France restauration', 'Carine Schmitt', '54, rue Royale', 'Nantes', '44000', 'France')
# ('Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy')
# ('Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez ', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal')
# ('Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña, 23', 'Barcelona', '08022', 'Spain')
# ('Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain')
# ('Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil')
# ('Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA')
# ('GROSELLA-Restaurante', 'Manuel Pereira', '5ª Ave. Los Palos Grandes', 'Caracas', '1081', 'Venezuela')
# ('Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil')
# ('HILARIÓN-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela')
# ('Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA')
# ('Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', None, 'Ireland')
# ('Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# ('Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany')
# ("La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France')
# ("La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France')
# ('Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada')
# ('Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA')
# ('Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M. ', '60528', 'Germany')
# ("Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA')
# ('LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela')
# ('LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela')
# ('Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA')
# ('Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy')
# ('Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium')
# ('Mère Paillarde', 'Jean Fresnière', '43 rue St. Laurent', 'Montréal', 'H1J 1C3', 'Canada')
# ('Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany')
# ('North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# ('Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina')
# ('Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA')
# ('Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany')
# ('Paris spécialités', 'Marie Bertrand', '265, boulevard Charonne', 'Paris', '75012', 'France')
# ('Pericles Comidas clásicas', 'Guillermo Fernández', 'Calle Dr. Jorge Cash 321', 'México D.F.', '05033', 'Mexico')
# ('Piccolo und mehr', 'Georg Pipps', 'Geislweg 14', 'Salzburg', '5020', 'Austria')
# ('Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal')
# ('Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil')
# ('Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil')
# ('QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany')
# ('Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina')
# ('Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA')
# ('Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy')
# ('Ricardo Adocicados', 'Janete Limeira', 'Av. Copacabana, 267', 'Rio de Janeiro', '02389-890', 'Brazil')
# ('Richter Supermarkt', 'Michael Holz', 'Grenzacherweg 237', 'Genève', '1203', 'Switzerland')
# ('Romero y tomillo', 'Alejandra Camino', 'Gran Vía, 1', 'Madrid', '28001', 'Spain')
# ('Santé Gourmet', 'Jonas Bergulfsen', 'Erling Skakkes gate 78', 'Stavern', '4110', 'Norway')
# ('Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')
# ('Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')
# ('Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'København', '1734', 'Denmark')
# ('Spécialités du monde', 'Dominique Perrier', '25, rue Lauriston', 'Paris', '75016', 'France')
# ('Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA')
# ('Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou, 255', 'Charleroi', 'B-6000', 'Belgium')
# ('The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA')
# ('The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA')
# ('Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany')
# ('Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico')
# ('Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro, 414', 'São Paulo', '05634-030', 'Brazil')
# ("Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA')
# ('Vaffeljernet', 'Palle Ibsen', 'Smagsløget 45', 'Århus', '8200', 'Denmark')
# ('Victuailles en stock', 'Mary Saveley', '2, rue du Commerce', 'Lyon', '69004', 'France')
# ('Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France')
# ('Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')
# ('Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland')
# ('Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil')
# ('White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA')
# ('Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland')
# ('Wolski', 'Zbyszek', 'ul. Filtrowa 68', 'Walla', '01-012', None)

# %%
pd.read_sql_query(query, conn)
# Out:
#                           CustomerName         ContactName  \
# 0                  Alfreds Futterkiste        Maria Anders
# 1   Ana Trujillo Emparedados y helados        Ana Trujillo
# 2              Antonio Moreno Taquería      Antonio Moreno
# 3                      Around the Horn        Thomas Hardy
# 4                   Berglunds snabbköp  Christina Berglund
# ..                                 ...                 ...
# 86                      Wartian Herkku    Pirkko Koskitalo
# 87              Wellington Importadora       Paula Parente
# 88                White Clover Markets      Karl Jablonski
# 89                         Wilman Kala     Matti Karttunen
# 90                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# 0                   Obere Str. 57       Berlin      12209  Germany
# 1   Avda. de la Constitución 2222  México D.F.      05021   Mexico
# 2                  Mataderos 2312  México D.F.      05023   Mexico
# 3                 120 Hanover Sq.       London    WA1 1DP       UK
# 4                  Berguvsvägen 8        Luleå   S-958 22   Sweden
# ..                            ...          ...        ...      ...
# 86                    Torikatu 38         Oulu      90110  Finland
# 87             Rua do Mercado, 12      Resende  08737-363   Brazil
# 88    305 - 14th Ave. S. Suite 3B      Seattle      98128      USA
# 89                  Keskuskatu 45     Helsinki      21240  Finland
# 90                ul. Filtrowa 68        Walla     01-012     None
#
# [91 rows x 6 columns]

# %%
cursor = conn.cursor()
query='SELECT CustomerName, City FROM Customers;'
cursor.execute(query)
for row in cursor:
    print(row)
# Out:
# ('Alfreds Futterkiste\xa0', 'Berlin\xa0')
# ('Ana Trujillo Emparedados y helados\xa0', 'México D.F.\xa0')
# ('Antonio Moreno Taquería\xa0', 'México D.F.\xa0')
# ('Around the Horn\xa0', 'London\xa0')
# ('Berglunds snabbköp\xa0', 'Luleå\xa0')
# ('Blauer See Delikatessen\xa0', 'Mannheim\xa0')
# ('Blondel père et fils\xa0', 'Strasbourg\xa0')
# ('Bólido Comidas preparadas\xa0', 'Madrid\xa0')
# ("Bon app'\xa0", 'Marseille\xa0')
# ('Bottom-Dollar Marketse\xa0', 'Tsawassen\xa0')
# ("B's Beverages\xa0", 'London\xa0')
# ('Cactus Comidas para llevar\xa0', 'Buenos Aires\xa0')
# ('Centro comercial Moctezuma\xa0', 'México D.F.\xa0')
# ('Chop-suey Chinese\xa0', 'Bern\xa0')
# ('Comércio Mineiro\xa0', 'São Paulo\xa0')
# ('Consolidated Holdings\xa0', 'London\xa0')
# ('Drachenblut Delikatessend\xa0', 'Aachen\xa0')
# ('Du monde entier\xa0', 'Nantes\xa0')
# ('Eastern Connection\xa0', 'London\xa0')
# ('Ernst Handel\xa0', 'Graz\xa0')
# ('Familia Arquibaldo\xa0', 'São Paulo\xa0')
# ('FISSA Fabrica Inter. Salchichas S.A.\xa0', 'Madrid\xa0')
# ('Folies gourmandes\xa0', 'Lille\xa0')
# ('Folk och fä HB\xa0', 'Bräcke\xa0')
# ('Frankenversand\xa0', 'München\xa0')
# ('France restauration\xa0', 'Nantes\xa0')
# ('Franchi S.p.A.\xa0', 'Torino\xa0')
# ('Furia Bacalhau e Frutos do Mar\xa0', 'Lisboa\xa0')
# ('Galería del gastrónomo\xa0', 'Barcelona\xa0')
# ('Godos Cocina Típica\xa0', 'Sevilla\xa0')
# ('Gourmet Lanchonetes\xa0', 'Campinas\xa0')
# ('Great Lakes Food Market\xa0', 'Eugene\xa0')
# ('GROSELLA-Restaurante\xa0', 'Caracas\xa0')
# ('Hanari Carnes\xa0', 'Rio de Janeiro\xa0')
# ('HILARIÓN-Abastos\xa0', 'San Cristóbal\xa0')
# ('Hungry Coyote Import Store\xa0', 'Elgin\xa0')
# ('Hungry Owl All-Night Grocers\xa0', 'Cork\xa0')
# ('Island Trading\xa0', 'Cowes\xa0')
# ('Königlich Essen\xa0', 'Brandenburg\xa0')
# ("La corne d'abondance\xa0", 'Versailles\xa0')
# ("La maison d'Asie\xa0", 'Toulouse\xa0')
# ('Laughing Bacchus Wine Cellars\xa0', 'Vancouver\xa0')
# ('Lazy K Kountry Store\xa0', 'Walla Walla\xa0')
# ('Lehmanns Marktstand\xa0', 'Frankfurt a.M. \xa0')
# ("Let's Stop N Shop\xa0", 'San Francisco\xa0')
# ('LILA-Supermercado\xa0', 'Barquisimeto\xa0')
# ('LINO-Delicateses\xa0', 'I. de Margarita\xa0')
# ('Lonesome Pine Restaurant\xa0', 'Portland\xa0')
# ('Magazzini Alimentari Riuniti\xa0', 'Bergamo\xa0')
# ('Maison Dewey\xa0', 'Bruxelles\xa0')
# ('Mère Paillarde\xa0', 'Montréal\xa0')
# ('Morgenstern Gesundkost\xa0', 'Leipzig\xa0')
# ('North/South\xa0', 'London\xa0')
# ('Océano Atlántico Ltda.\xa0', 'Buenos Aires\xa0')
# ('Old World Delicatessen\xa0', 'Anchorage\xa0')
# ('Ottilies Käseladen\xa0', 'Köln\xa0')
# ('Paris spécialités\xa0', 'Paris\xa0')
# ('Pericles Comidas clásicas\xa0', 'México D.F.\xa0')
# ('Piccolo und mehr\xa0', 'Salzburg\xa0')
# ('Princesa Isabel Vinhoss\xa0', 'Lisboa\xa0')
# ('Que Delícia\xa0', 'Rio de Janeiro\xa0')
# ('Queen Cozinha\xa0', 'São Paulo\xa0')
# ('QUICK-Stop\xa0', 'Cunewalde\xa0')
# ('Rancho grande\xa0', 'Buenos Aires\xa0')
# ('Rattlesnake Canyon Grocery\xa0', 'Albuquerque\xa0')
# ('Reggiani Caseifici\xa0', 'Reggio Emilia\xa0')
# ('Ricardo Adocicados\xa0', 'Rio de Janeiro\xa0')
# ('Richter Supermarkt\xa0', 'Genève\xa0')
# ('Romero y tomillo\xa0', 'Madrid\xa0')
# ('Santé Gourmet\xa0', 'Stavern\xa0')
# ('Save-a-lot Markets\xa0', 'Boise\xa0')
# ('Seven Seas Imports\xa0', 'London\xa0')
# ('Simons bistro\xa0', 'København\xa0')
# ('Spécialités du monde\xa0', 'Paris\xa0')
# ('Split Rail Beer & Ale\xa0', 'Lander\xa0')
# ('Suprêmes délices\xa0', 'Charleroi\xa0')
# ('The Big Cheese\xa0', 'Portland\xa0')
# ('The Cracker Box\xa0', 'Butte\xa0')
# ('Toms Spezialitäten\xa0', 'Münster\xa0')
# ('Tortuga Restaurante\xa0', 'México D.F.\xa0')
# ('Tradição Hipermercados\xa0', 'São Paulo\xa0')
# ("Trail's Head Gourmet Provisioners\xa0", 'Kirkland\xa0')
# ('Vaffeljernet\xa0', 'Århus\xa0')
# ('Victuailles en stock\xa0', 'Lyon\xa0')
# ('Vins et alcools Chevalier\xa0', 'Reims\xa0')
# ('Die Wandernde Kuh\xa0', 'Stuttgart\xa0')
# ('Wartian Herkku\xa0', 'Oulu\xa0')
# ('Wellington Importadora\xa0', 'Resende\xa0')
# ('White Clover Markets\xa0', 'Seattle\xa0')
# ('Wilman Kala\xa0', 'Helsinki\xa0')
# ('Wolski\xa0', 'Walla\xa0')

# %%
cursor = conn.cursor()
query='SELECT DISTINCT Country FROM Customers;'
cursor.execute(query)
for row in cursor:
    print(row)
# Out:
# ('Germany\xa0',)
# ('Mexico\xa0',)
# ('UK\xa0',)
# ('Sweden\xa0',)
# ('France\xa0',)
# ('Spain\xa0',)
# ('Canada\xa0',)
# ('Argentina\xa0',)
# ('Switzerland\xa0',)
# ('Brazil\xa0',)
# ('Austria\xa0',)
# ('Italy\xa0',)
# ('Portugal\xa0',)
# ('USA\xa0',)
# ('Venezuela\xa0',)
# ('Ireland\xa0',)
# ('Belgium\xa0',)
# ('Norway\xa0',)
# ('Denmark\xa0',)
# ('Finland\xa0',)
# (None,)

# %%
cursor = conn.cursor()
query="SELECT * FROM Customers WHERE Country='Mexico ';"
cursor.execute(query)
for row in cursor:
    print(row)
# Out:
# ('2\xa0', 'Ana Trujillo Emparedados y helados\xa0', 'Ana Trujillo\xa0', 'Avda. de la Constitución 2222\xa0', 'México D.F.\xa0', '05021\xa0', 'Mexico\xa0')
# ('3\xa0', 'Antonio Moreno Taquería\xa0', 'Antonio Moreno\xa0', 'Mataderos 2312\xa0', 'México D.F.\xa0', '05023\xa0', 'Mexico\xa0')
# ('13\xa0', 'Centro comercial Moctezuma\xa0', 'Francisco Chang\xa0', 'Sierras de Granada 9993\xa0', 'México D.F.\xa0', '05022\xa0', 'Mexico\xa0')
# ('58\xa0', 'Pericles Comidas clásicas\xa0', 'Guillermo Fernández\xa0', 'Calle Dr. Jorge Cash 321\xa0', 'México D.F.\xa0', '05033\xa0', 'Mexico\xa0')
# ('80\xa0', 'Tortuga Restaurante\xa0', 'Miguel Angel Paolino\xa0', 'Avda. Azteca 123\xa0', 'México D.F.\xa0', '05033\xa0', 'Mexico\xa0')

# %%
cursor = conn.cursor()
query='SELECT * FROM Products ORDER BY Price;'
cursor.execute(query)
for row in cursor:
    print(row)
# Out:
# ('3\xa0', 'Aniseed Syrup\xa0', '1\xa0', '2\xa0', '12 - 550 ml bottles\xa0', '10\xa0')
# ('21\xa0', "Sir Rodney's Scones\xa0", '8\xa0', '3\xa0', '24 pkgs. x 4 pieces\xa0', '10\xa0')
# ('74\xa0', 'Longlife Tofu\xa0', '4\xa0', '7\xa0', '5 kg pkg.\xa0', '10\xa0')
# ('31\xa0', 'Gorgonzola Telino\xa0', '14\xa0', '4\xa0', '12 - 100 g pkgs\xa0', '12.5\xa0')
# ('68\xa0', 'Scottish Longbreads\xa0', '8\xa0', '3\xa0', '10 boxes x 8 pieces\xa0', '12.5\xa0')
# ('48\xa0', 'Chocolade\xa0', '22\xa0', '3\xa0', '10 pkgs.\xa0', '12.75\xa0')
# ('29\xa0', 'Thüringer Rostbratwurst\xa0', '12\xa0', '6\xa0', '50 bags x 30 sausgs.\xa0', '123.79\xa0')
# ('46\xa0', 'Spegesild\xa0', '21\xa0', '8\xa0', '4 - 450 g glasses\xa0', '12\xa0')
# ('58\xa0', 'Escargots de Bourgogne\xa0', '27\xa0', '8\xa0', '24 pieces\xa0', '13.25\xa0')
# ('77\xa0', 'Original Frankfurter grüne Soße\xa0', '12\xa0', '2\xa0', '12 boxes\xa0', '13\xa0')
# ('25\xa0', 'NuNuCa Nuß-Nougat-Creme\xa0', '11\xa0', '3\xa0', '20 - 450 g glasses\xa0', '14\xa0')
# ('34\xa0', 'Sasquatch Ale\xa0', '16\xa0', '1\xa0', '24 - 12 oz bottles\xa0', '14\xa0')
# ('42\xa0', 'Singaporean Hokkien Fried Mee\xa0', '20\xa0', '5\xa0', '32 - 1 kg pkgs.\xa0', '14\xa0')
# ('67\xa0', 'Laughing Lumberjack Lager\xa0', '16\xa0', '1\xa0', '24 - 12 oz bottles\xa0', '14\xa0')
# ('15\xa0', 'Genen Shouyu\xa0', '6\xa0', '2\xa0', '24 - 250 ml bottles\xa0', '15.5\xa0')
# ('70\xa0', 'Outback Lager\xa0', '7\xa0', '1\xa0', '24 - 355 ml bottles\xa0', '15\xa0')
# ('73\xa0', 'Röd Kaviar\xa0', '17\xa0', '8\xa0', '24 - 150 g jars\xa0', '15\xa0')
# ('50\xa0', 'Valkoinen suklaa\xa0', '23\xa0', '3\xa0', '12 - 100 g bars\xa0', '16.25\xa0')
# ('16\xa0', 'Pavlova\xa0', '7\xa0', '3\xa0', '32 - 500 g boxes\xa0', '17.45\xa0')
# ('66\xa0', 'Louisiana Hot Spiced Okra\xa0', '2\xa0', '2\xa0', '24 - 8 oz jars\xa0', '17\xa0')
# ('40\xa0', 'Boston Crab Meat\xa0', '19\xa0', '8\xa0', '24 - 4 oz tins\xa0', '18.4\xa0')
# ('1\xa0', 'Chais\xa0', '1\xa0', '1\xa0', '10 boxes x 20 bags\xa0', '18\xa0')
# ('35\xa0', 'Steeleye Stout\xa0', '16\xa0', '1\xa0', '24 - 12 oz bottles\xa0', '18\xa0')
# ('39\xa0', 'Chartreuse verte\xa0', '18\xa0', '1\xa0', '750 cc per bottle\xa0', '18\xa0')
# ('76\xa0', 'Lakkalikööri\xa0', '23\xa0', '1\xa0', '500 ml \xa0', '18\xa0')
# ('44\xa0', 'Gula Malacca\xa0', '20\xa0', '2\xa0', '20 - 2 kg bags\xa0', '19.45\xa0')
# ('57\xa0', 'Ravioli Angelo\xa0', '26\xa0', '5\xa0', '24 - 250 g pkgs.\xa0', '19.5\xa0')
# ('2\xa0', 'Chang\xa0', '1\xa0', '1\xa0', '24 - 12 oz bottles\xa0', '19\xa0')
# ('36\xa0', 'Inlagd Sill\xa0', '17\xa0', '8\xa0', '24 - 250 g jars\xa0', '19\xa0')
# ('33\xa0', 'Geitost\xa0', '15\xa0', '4\xa0', '500 g\xa0', '2.5\xa0')
# ('49\xa0', 'Maxilaku\xa0', '23\xa0', '3\xa0', '24 - 50 g pkgs.\xa0', '20\xa0')
# ('65\xa0', 'Louisiana Fiery Hot Pepper Sauce\xa0', '2\xa0', '2\xa0', '32 - 8 oz bottles\xa0', '21.05\xa0')
# ('5\xa0', "Chef Anton's Gumbo Mix\xa0", '2\xa0', '2\xa0', '36 boxes\xa0', '21.35\xa0')
# ('71\xa0', 'Fløtemysost\xa0', '15\xa0', '4\xa0', '10 - 500 g pkgs.\xa0', '21.5\xa0')
# ('11\xa0', 'Queso Cabrales\xa0', '5\xa0', '4\xa0', '1 kg pkg.\xa0', '21\xa0')
# ('22\xa0', "Gustaf's Knäckebröd\xa0", '9\xa0', '5\xa0', '24 - 500 g pkgs.\xa0', '21\xa0')
# ('4\xa0', "Chef Anton's Cajun Seasoning\xa0", '2\xa0', '2\xa0', '48 - 6 oz jars\xa0', '22\xa0')
# ('14\xa0', 'Tofu\xa0', '6\xa0', '7\xa0', '40 - 100 g pkgs.\xa0', '23.25\xa0')
# ('55\xa0', 'Pâté chinois\xa0', '25\xa0', '6\xa0', '24 boxes x 2 pies\xa0', '24\xa0')
# ('30\xa0', 'Nord-Ost Matjeshering\xa0', '13\xa0', '8\xa0', '10 - 200 g glasses\xa0', '25.89\xa0')
# ('6\xa0', "Grandma's Boysenberry Spread\xa0", '3\xa0', '2\xa0', '12 - 8 oz jars\xa0', '25\xa0')
# ('38\xa0', 'Côte de Blaye\xa0', '18\xa0', '1\xa0', '12 - 75 cl bottles\xa0', '263.5\xa0')
# ('37\xa0', 'Gravad lax\xa0', '17\xa0', '8\xa0', '12 - 500 g pkgs.\xa0', '26\xa0')
# ('61\xa0', "Sirop d'érable\xa0", '29\xa0', '2\xa0', '24 - 500 ml bottles\xa0', '28.5\xa0')
# ('7\xa0', "Uncle Bob's Organic Dried Pears\xa0", '3\xa0', '7\xa0', '12 - 1 lb pkgs.\xa0', '30\xa0')
# ('26\xa0', 'Gumbär Gummibärchen\xa0', '11\xa0', '3\xa0', '100 - 250 g bags\xa0', '31.23\xa0')
# ('10\xa0', 'Ikura\xa0', '4\xa0', '8\xa0', '12 - 200 ml jars\xa0', '31\xa0')
# ('53\xa0', 'Perth Pasties\xa0', '24\xa0', '6\xa0', '48 pieces\xa0', '32.8\xa0')
# ('32\xa0', 'Mascarpone Fabioli\xa0', '14\xa0', '4\xa0', '24 - 200 g pkgs.\xa0', '32\xa0')
# ('64\xa0', 'Wimmers gute Semmelknödel\xa0', '12\xa0', '5\xa0', '20 bags x 4 pieces\xa0', '33.25\xa0')
# ('72\xa0', 'Mozzarella di Giovanni\xa0', '14\xa0', '4\xa0', '24 - 200 g pkgs.\xa0', '34.8\xa0')
# ('60\xa0', 'Camembert Pierrot\xa0', '28\xa0', '4\xa0', '15 - 300 g rounds\xa0', '34\xa0')
# ('69\xa0', 'Gudbrandsdalsost\xa0', '15\xa0', '4\xa0', '10 kg pkg.\xa0', '36\xa0')
# ('12\xa0', 'Queso Manchego La Pastora\xa0', '5\xa0', '4\xa0', '10 - 500 g pkgs.\xa0', '38\xa0')
# ('56\xa0', 'Gnocchi di nonna Alice\xa0', '26\xa0', '5\xa0', '24 - 250 g pkgs.\xa0', '38\xa0')
# ('17\xa0', 'Alice Mutton\xa0', '7\xa0', '6\xa0', '20 - 1 kg tins\xa0', '39\xa0')
# ('24\xa0', 'Guaraná Fantástica\xa0', '10\xa0', '1\xa0', '12 - 355 ml cans\xa0', '4.5\xa0')
# ('8\xa0', 'Northwoods Cranberry Sauce\xa0', '3\xa0', '2\xa0', '12 - 12 oz jars\xa0', '40\xa0')
# ('27\xa0', 'Schoggi Schokolade\xa0', '11\xa0', '3\xa0', '100 - 100 g pieces\xa0', '43.9\xa0')
# ('63\xa0', 'Vegie-spread\xa0', '7\xa0', '2\xa0', '15 - 625 g jars\xa0', '43.9\xa0')
# ('28\xa0', 'Rössle Sauerkraut\xa0', '12\xa0', '7\xa0', '25 - 825 g cans\xa0', '45.6\xa0')
# ('43\xa0', 'Ipoh Coffee\xa0', '20\xa0', '1\xa0', '16 - 500 g tins\xa0', '46\xa0')
# ('62\xa0', 'Tarte au sucre\xa0', '29\xa0', '3\xa0', '48 pies\xa0', '49.3\xa0')
# ('51\xa0', 'Manjimup Dried Apples\xa0', '24\xa0', '7\xa0', '50 - 300 g pkgs.\xa0', '53\xa0')
# ('59\xa0', 'Raclette Courdavault\xa0', '28\xa0', '4\xa0', '5 kg pkg.\xa0', '55\xa0')
# ('18\xa0', 'Carnarvon Tigers\xa0', '7\xa0', '8\xa0', '16 kg pkg.\xa0', '62.5\xa0')
# ('13\xa0', 'Konbu\xa0', '6\xa0', '8\xa0', '2 kg box\xa0', '6\xa0')
# ('54\xa0', 'Tourtière\xa0', '25\xa0', '6\xa0', '16 pies\xa0', '7.45\xa0')
# ('75\xa0', 'Rhönbräu Klosterbier\xa0', '12\xa0', '1\xa0', '24 - 0.5 l bottles\xa0', '7.75\xa0')
# ('52\xa0', 'Filo Mix\xa0', '24\xa0', '5\xa0', '16 - 2 kg boxes\xa0', '7\xa0')
# ('20\xa0', "Sir Rodney's Marmalade\xa0", '8\xa0', '3\xa0', '30 gift boxes\xa0', '81\xa0')
# ('19\xa0', 'Teatime Chocolate Biscuits\xa0', '8\xa0', '3\xa0', '10 boxes x 12 pieces\xa0', '9.2\xa0')
# ('45\xa0', 'Røgede sild\xa0', '21\xa0', '8\xa0', '1k pkg.\xa0', '9.5\xa0')
# ('47\xa0', 'Zaanse koeken\xa0', '22\xa0', '3\xa0', '10 - 4 oz boxes\xa0', '9.5\xa0')
# ('41\xa0', "Jack's New England Clam Chowder\xa0", '19\xa0', '8\xa0', '12 - 12 oz cans\xa0', '9.65\xa0')
# ('9\xa0', 'Mishi Kobe Niku\xa0', '4\xa0', '6\xa0', '18 - 500 g pkgs.\xa0', '97\xa0')
# ('23\xa0', 'Tunnbröd\xa0', '9\xa0', '5\xa0', '12 - 250 g pkgs.\xa0', '9\xa0')

# %%
cursor = conn.cursor()

query="SELECT * FROM Customers WHERE Country = 'Spain ' AND CustomerName LIKE 'G%';"
cursor.execute(query)
for row in cursor:
    print(row)
# Out:
# ('29\xa0', 'Galería del gastrónomo\xa0', 'Eduardo Saavedra\xa0', 'Rambla de Cataluña, 23\xa0', 'Barcelona\xa0', '08022\xa0', 'Spain\xa0')
# ('30\xa0', 'Godos Cocina Típica\xa0', 'José Pedro Freyre\xa0', 'C/ Romero, 33\xa0', 'Sevilla\xa0', '41101\xa0', 'Spain\xa0')
